# %% [markdown]
# <a href="https://colab.research.google.com/github/notyourfriends/Kaggle/blob/main/Cheat%20Sheet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/notyourfriends/Kaggle/main/Datasets/cancer.csv'
cancer_data = pd.read_csv(url, encoding = 'unicode_escape')
cancer_data
# Out:
#            Id Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# 0     8510426         B         13.540           14.36             87.46
# 1     8510653         B         13.080           15.71             85.63
# 2     8510824         B          9.504           12.44             60.34
# 3      854941         B         13.030           18.42             82.61
# 4    85713702         B          8.196           16.84             51.71
# ..        ...       ...            ...             ...               ...
# 564    926125         M         20.920           25.09            143.00
# 565    926424         M         21.560           22.39            142.00
# 566    926682         M         20.130           28.25            131.20
# 567    926954         M         16.600           28.08            108.30
# 568    927241         M         20.600           29.33            140.10
#
#      Area (mean)  Smoothness (mean)  Compactness (mean)  Concavity (mean)  \
# ...

# %%
plt.figure(figsize=(16, 6))
sns.lineplot(data=cancer_data['Radius (mean)'])
plt.title('Radius (mean)')
# Out:
# Text(0.5, 1.0, 'Radius (mean)')
